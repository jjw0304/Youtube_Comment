# %%
from bs4 import BeautifulSoup
import selenium
import time

# %%
chrome_driver_path = r'C:\Users\jjw03\Downloads\chromedriver.exe'  # chrome driver의 경로
driver = webdriver.Chrome(chrome_driver_path)
data = []

driver.get('https://www.youtube.com/watch?v=HbST1SnRTos')

elem = driver.find_element_by_tag_name("body") 
pagedowns = 1
while pagedowns < 20:
        elem.send_keys(Keys.PAGE_DOWN)
        time.sleep(1)
        pagedowns += 1

html = driver.page_source
soup = BeautifulSoup(html)
table = soup.find('ytd-item-section-renderer', {'class' : 'style-scope ytd-comments'})

# %%
table
# Out:
# <ytd-item-section-renderer class="style-scope ytd-comments" id="sections" initial-count="2">
# <div class="style-scope ytd-item-section-renderer" id="header"><ytd-comments-header-renderer class="style-scope ytd-item-section-renderer">
# <div class="style-scope ytd-comments-header-renderer" id="title">
# <h2 class="style-scope ytd-comments-header-renderer" id="count">
# <yt-formatted-string class="count-text style-scope ytd-comments-header-renderer">댓글 135개</yt-formatted-string>
# </h2>
# <span class="style-scope ytd-comments-header-renderer" id="sort-menu"><yt-sort-filter-sub-menu-renderer class="style-scope ytd-comments-header-renderer">
# <paper-tooltip class="style-scope yt-sort-filter-sub-menu-renderer" role="tooltip" tabindex="-1"><!--css-build:shady-->
# <div class="hidden style-scope paper-tooltip" id="tooltip">
#       댓글 정렬
#     </div>
# </paper-tooltip>
# <yt-dropdown-menu class="style-scope yt-sort-filter-sub-menu-renderer has-items">
# ...
